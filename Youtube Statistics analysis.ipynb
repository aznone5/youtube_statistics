# %% [markdown]
# ## By Jackie Nguyen
# * github: https://github.com/aznone5
# * linkedin: https://www.linkedin.com/in/jackie-dan-nguyen/
# * Kaggle DataSet: https://www.kaggle.com/datasets/nelgiriyewithana/global-youtube-statistics-2023

# %% [markdown]
# ## About This Dataset
# 1. This Dataset collects 1000 of the most subscribed channels.
# 2. We will be looking at different key features that been aggerated in Sql where you can look in the github sql file.
# 3. The most important columns we will be intrested is subscribers, video viewsm category, upload, country, and all the earnings the channel produced.
# 4. The analytics we can learn from this are what content strategies work, regional influence, earning analysis, and category trends.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread("C:/Users/Jacki/anaconda mini/Youtube sql/Category_information.jpeg")


plt.figure(figsize=(60, 60))
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# From these 3 tables, we can see what dominate in terms in number of youtube categories is entertainment, music, people and blogs, and gamming.  Profit seems to correlate with now much channels are there for the major categories, but news and politics upload significant amount of videos in comparison to others, but dont profit as much in comparision.  On the otherhand, Music tends to profit alot but makes significantly less videos in comparison to entertainment and people and blogs.  Although it is true that production quality and resources of a music video tends to be alot higher than making a blog.

# %%
img = mpimg.imread("C:/Users/Jacki/anaconda mini/Youtube sql/Income.jpeg")


plt.figure(figsize=(40, 40))
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# NOTE, this is income from ad revenue only.  Most youtubers or these channels get sponsorship deals, record deals, or make other incomes through different ways other than ad revenue.  Also, each channel gets a certain rate of ad revenue that can't be calculated fully.  The ad revenue rate depends on how many ads are in what video, skippable vs non-skippable ads, and some channels are old and didn't make that much money 10 years ago, but make a significant amount now.  For example T-series videos can have alot of views.  They have 7-1billion viewed videos, but they make so many videos and their other videos don't get that many views that their profit per video isn't top 20.  It's a easy trend to see that Music Vevo Channels or offical artist channels make the most per video.

# %%
img = mpimg.imread("C:/Users/Jacki/anaconda mini/Youtube sql/Subs.jpeg")


plt.figure(figsize=(40, 40))
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# Of course, United States dominate the Youtube Scene, an american based company. India have a notable amount and the most Subscribers tend to be companies or artist or music groups.  Only Mrbeast and Pewdiepie are considered 'Youtubers'.

# %% [markdown]
# ## Conclusion
# Even Though T-series is the most Subscribed channel, the profits it makes per video and production cost to make those vidoes are mostlikey not the best ROI returned on most of their videos. Someone like MrBeast may not get billions, currently he has a significantly more probabilty to garentee a ROI on his videos, as his videos always average 100's of millions of views.  Buisness like garentee probability over chances of a viral video and a large range of views per video.  Even if MrBeast videos on average throughout his career produce a high income from his peers, the average yearly income should go up when next years youtube statistic dataset comes around.
#     We can conclude that entertainment and music are going to dominate the category charts.  With short content being a huge thing, and people like watching music videos.  The best way to make money from youtube would be to make videos in those type of categories.
